# %%
# without dates
import data_helpers_neutrals

fpaths = [r'C:\Users\OP\OneDrive\APG\code\AI_team_CNN_v0.1\data\companyTweets\samsungTweets.txt',
         r'C:\Users\OP\OneDrive\APG\code\AI_team_CNN_v0.1\data\rt-polarity.test']
for fpath in fpaths:
    file = open(fpath,'r')
    neutrals = open(r'data\rt-polarity.neu','a')

    for line in file:
        neutrals.write(data_helpers_neutrals.clean_str(line)+'\n')

    neutrals.close()
    file.close()

# %%
# PRAVEEN AND BART, RUN THIS ONE, DELETE CURRENT .neu FILE BEFORE YOU DO THIS!
# with dates

import data_helpers_neutrals

fpath1 = r'C:\Users\OP\OneDrive\APG\code\AI_team_CNN_v0.1\data\companyTweets\samsungTweets.txt'
fpath2 = r'C:\Users\OP\OneDrive\APG\code\AI_team_CNN_v0.1\data\rt-polarity.test'
company = open(fpath1,'r')
test = open(fpath2,'r')
neutrals = open(r'data\rt-polarity.neu','a')

files = [company, test]
    
for line in company:
    line = line[20::] #this takes away the date
    neutrals.write(data_helpers_neutrals.clean_str(line)+'\n')
    
for line in test:
    neutrals.write(data_helpers_neutrals.clean_str(line)+'\n')

neutrals.close()
company.close()
test.close()

# write articles to neutral files
import data_helpers_neutrals

articles = open(r"E:\efund\articles.tsv")
neutrals = open(r'data\rt-polarity.neu','a')
for line in articles:
    if len(line)>49:
        neutrals.write(data_helpers_neutrals.clean_str(line)+'\n')
neutrals.close()
articles.close()
