# %%
import pandas as pd

samdata = pd.read_csv(r"C:\Users\OP\Downloads\sam_data\sam_data.tsv",delimiter="\t",error_bad_lines=False)
print("Total number of tweets = ",len(samdata.iloc[:,7]))
# Out:
# b'Skipping line 50786: expected 15 fields, saw 27\nSkipping line 52650: expected 15 fields, saw 18\nSkipping line 53741: expected 15 fields, saw 18\nSkipping line 55580: expected 15 fields, saw 18\nSkipping line 56896: expected 15 fields, saw 18\nSkipping line 61868: expected 15 fields, saw 21\n'
# ...

# %%
file = open('data/rt-polarity.neu', "w")
no_save_tweets = 100000

counter = 0
for line in samdata.iloc[:,7]:
    counter +=1
    if counter<no_save_tweets:
        file.write(line+"\n")
    else:
        break

file.close()
